# %%
import pandas as pd

# %%
tickets = pd.read_csv('datos/tickets_soporte_q1.csv')
clientes = pd.read_csv('datos/clientes_soporte.csv')
estados = pd.read_csv('datos/estados_ticket.csv')

print("Tickets")
display(tickets.head())

print("Clientes")
display(clientes.head())

print("Estados")
display(estados.head())
# Out:
# Tickets
#    id_ticket fec_apertura  id_cli    cat_incid   prio  st_cod canal_orig reg  \
# 0       5001   2026-01-05     120      Entrega  Media       1        Web  CL
# 1       5002   2026-01-08     115      Entrega  Media       2     Tienda  MX
# 2       5003   2026-01-09     110     Producto   Alta       3        Web  AR
# 3       5004   2026-01-12     115     Producto   Baja       4     Tienda  CL
# 4       5005   2026-01-11     120  Facturación   Baja       5        Web  MX
#
#    hrs_res  nps
# 0     37.1  2.0
# 1     57.3  2.0
# 2     68.9  1.0
# 3     66.8  5.0
# 4     34.1  1.0
# Clientes
#    id_cli  nombre_cliente   segmento
# 0     100  María González    Premium
# 1     101     Carlos Ruiz     Retail
# 2     102    Ana Martínez    Premium
# 3     103  Luis Fernández     Retail
# 4     104     Sofía López  Corporate
# Estados
#    st_cod estado_visible  es_final
# 0       1          Nuevo     False
# 1       2       Asignado     False
# 2       3       En curso     False
# ...

# %%
df = tickets.copy() # creamos una copia de Tickets en la varialble df, motivo preservar los datos orignales

df.head()
# Out:
#    id_ticket fec_apertura  id_cli    cat_incid   prio  st_cod canal_orig reg  \
# 0       5001   2026-01-05     120      Entrega  Media       1        Web  CL
# 1       5002   2026-01-08     115      Entrega  Media       2     Tienda  MX
# 2       5003   2026-01-09     110     Producto   Alta       3        Web  AR
# 3       5004   2026-01-12     115     Producto   Baja       4     Tienda  CL
# 4       5005   2026-01-11     120  Facturación   Baja       5        Web  MX
#
#    hrs_res  nps
# 0     37.1  2.0
# 1     57.3  2.0
# 2     68.9  1.0
# 3     66.8  5.0
# 4     34.1  1.0

# %%
df.info() 
# .info() nos muestra el los tipos de datos de cada columna
# la cantidad de datos no nulos
# la cantidad registros
# la memoria que ocupa el DF
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_ticket     50 non-null     int64
#  1   fec_apertura  50 non-null     str
#  2   id_cli        50 non-null     int64
#  3   cat_incid     50 non-null     str
#  4   prio          50 non-null     str
#  5   st_cod        50 non-null     int64
#  6   canal_orig    50 non-null     str
#  7   reg           50 non-null     str
#  8   hrs_res       47 non-null     float64
#  9   nps           49 non-null     float64
# dtypes: float64(2), int64(3), str(5)
# memory usage: 4.0 KB

# %% [markdown]
# ### Observaciones
# - Cambiar el tipo de dato a `fec_apertura` por formato fecha
# - Revisar lso datos nulso de `hrs_res` y de `nps`
# - Cambiar el nombre de las columnas .... ID_Ticket ID Cliente, Il1 id_ticket

# %%
display(df.describe().T)
# Out:
#         id_ticket      id_cli     st_cod    hrs_res        nps
# count    50.00000   50.000000  50.000000  47.000000  49.000000
# mean   5025.50000  109.540000   3.000000  30.323404   3.204082
# std      14.57738    8.933336   1.428571  19.708244   1.471671
# min    5001.00000  100.000000   1.000000   0.700000   1.000000
# 25%    5013.25000  102.000000   2.000000  15.400000   2.000000
# 50%    5025.50000  107.500000   3.000000  28.900000   3.000000
# 75%    5037.75000  115.000000   4.000000  43.750000   4.000000
# max    5050.00000  130.000000   5.000000  68.900000   5.000000

# %%
display(df.describe().T)
# Out:
#            count         mean        std     min      25%     50%      75%  \
# id_ticket   50.0  5025.500000  14.577380  5001.0  5013.25  5025.5  5037.75
# id_cli      50.0   109.540000   8.933336   100.0   102.00   107.5   115.00
# st_cod      50.0     3.000000   1.428571     1.0     2.00     3.0     4.00
# hrs_res     47.0    30.323404  19.708244     0.7    15.40    28.9    43.75
# nps         49.0     3.204082   1.471671     1.0     2.00     3.0     4.00
#
#               max
# id_ticket  5050.0
# id_cli      130.0
# st_cod        5.0
# hrs_res      68.9
# nps           5.0

# %% [markdown]
# - Revisar datos nulos de estas atributos (ejemplo id_ticket)
# - Revisar los outliers (valores atipicos) de estas atributos (ejemplo id_ticket)
# - Otros

# %%
df.head()
# Out:
#    id_ticket fec_apertura  id_cli    cat_incid   prio  st_cod canal_orig reg  \
# 0       5001   2026-01-05     120      Entrega  Media       1        Web  CL
# 1       5002   2026-01-08     115      Entrega  Media       2     Tienda  MX
# 2       5003   2026-01-09     110     Producto   Alta       3        Web  AR
# 3       5004   2026-01-12     115     Producto   Baja       4     Tienda  CL
# 4       5005   2026-01-11     120  Facturación   Baja       5        Web  MX
#
#    hrs_res  nps
# 0     37.1  2.0
# 1     57.3  2.0
# 2     68.9  1.0
# 3     66.8  5.0
# 4     34.1  1.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.columns
# Out:
# Index(['id_ticket', 'fec_apertura', 'id_cli', 'cat_incid', 'prio', 'st_cod',
#        'canal_orig', 'reg', 'hrs_res', 'nps'],
#       dtype='str')

# %%
df_1 = df.copy()
df_1 = df_1.rename(columns={
    "fec_apertura": "fecha_alta",
    "prio": "prioridad",
    "nps": "Net Promoter Score"
})

# %%
df_1.head()
# Out:
#    id_ticket  fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig  \
# 0       5001  2026-01-05     120      Entrega     Media       1        Web
# 1       5002  2026-01-08     115      Entrega     Media       2     Tienda
# 2       5003  2026-01-09     110     Producto      Alta       3        Web
# 3       5004  2026-01-12     115     Producto      Baja       4     Tienda
# 4       5005  2026-01-11     120  Facturación      Baja       5        Web
#
#   reg  hrs_res  Net Promoter Score
# 0  CL     37.1                 2.0
# 1  MX     57.3                 2.0
# 2  AR     68.9                 1.0
# 3  CL     66.8                 5.0
# 4  MX     34.1                 1.0

# %%
df_1 = df_1.rename(columns={"Net Promoter Score":"nps"})

# %%
df_1.head()
# Out:
#    id_ticket  fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig  \
# 0       5001  2026-01-05     120      Entrega     Media       1        Web
# 1       5002  2026-01-08     115      Entrega     Media       2     Tienda
# 2       5003  2026-01-09     110     Producto      Alta       3        Web
# 3       5004  2026-01-12     115     Producto      Baja       4     Tienda
# 4       5005  2026-01-11     120  Facturación      Baja       5        Web
#
#   reg  hrs_res  nps
# 0  CL     37.1  2.0
# 1  MX     57.3  2.0
# 2  AR     68.9  1.0
# 3  CL     66.8  5.0
# 4  MX     34.1  1.0

# %%
df_1 = df_1.set_index("id_ticket")
df_1.head()
# Out:
#            fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig reg  \
# id_ticket
# 5001       2026-01-05     120      Entrega     Media       1        Web  CL
# 5002       2026-01-08     115      Entrega     Media       2     Tienda  MX
# 5003       2026-01-09     110     Producto      Alta       3        Web  AR
# 5004       2026-01-12     115     Producto      Baja       4     Tienda  CL
# 5005       2026-01-11     120  Facturación      Baja       5        Web  MX
#
#            hrs_res  nps
# id_ticket
# 5001          37.1  2.0
# 5002          57.3  2.0
# 5003          68.9  1.0
# 5004          66.8  5.0
# 5005          34.1  1.0

# %%
# df1 contiene nombres de columnas modificados
df_1.loc[5002]
# Out:
# fecha_alta    2026-01-08
# id_cli               115
# cat_incid        Entrega
# prioridad          Media
# st_cod                 2
# canal_orig        Tienda
# reg                   MX
# hrs_res             57.3
# nps                  2.0
# Name: 5002, dtype: object

# %%
# df es la primera copia de los datos originales de Tickets
df.loc[1]
# Out:
# id_ticket             5002
# fec_apertura    2026-01-08
# id_cli                 115
# cat_incid          Entrega
# prio                 Media
# st_cod                   2
# canal_orig          Tienda
# reg                     MX
# hrs_res               57.3
# nps                    2.0
# Name: 1, dtype: object

# %%
df_1.loc[5002, "cat_incid"]
# Out:
# 'Entrega'

# %%
df_1.loc[5005, "canal_orig"]
# Out:
# 'Web'

# %%
df_1.loc[[5002, 5005, 5030, 5041], ["id_cli", "fecha_alta", "canal_orig", "prioridad"]]
# Out:
#            id_cli  fecha_alta   canal_orig prioridad
# id_ticket
# 5002          115  2026-01-08       Tienda     Media
# 5005          120  2026-01-11          Web      Baja
# 5030          110  2026-02-23  Marketplace      Alta
# 5041          102  2026-03-14       Tienda   Crítica

# %%
display(df_1.describe(include="str").T)
display(df_1.describe(include="number").T)
display(df_1.describe(include="all").T)
# Out:
#            count unique         top freq
# fecha_alta    50     45  2026-01-15    2
# cat_incid     50      6    Producto   12
# prioridad     50      4        Alta   17
# canal_orig    50      3         Web   24
# reg           50      3          CL   18
#          count        mean        std    min    25%    50%     75%    max
# id_cli    50.0  109.540000   8.933336  100.0  102.0  107.5  115.00  130.0
# st_cod    50.0    3.000000   1.428571    1.0    2.0    3.0    4.00    5.0
# hrs_res   47.0   30.323404  19.708244    0.7   15.4   28.9   43.75   68.9
# nps       49.0    3.204082   1.471671    1.0    2.0    3.0    4.00    5.0
#            count unique         top freq       mean        std    min    25%  \
# fecha_alta    50     45  2026-01-15    2        NaN        NaN    NaN    NaN
# id_cli      50.0    NaN         NaN  NaN     109.54   8.933336  100.0  102.0
# cat_incid     50      6    Producto   12        NaN        NaN    NaN    NaN
# ...

# %%
df_1.head()
# Out:
#            fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig reg  \
# id_ticket
# 5001       2026-01-05     120      Entrega     Media       1        Web  CL
# 5002       2026-01-08     115      Entrega     Media       2     Tienda  MX
# 5003       2026-01-09     110     Producto      Alta       3        Web  AR
# 5004       2026-01-12     115     Producto      Baja       4     Tienda  CL
# 5005       2026-01-11     120  Facturación      Baja       5        Web  MX
#
#            hrs_res  nps
# id_ticket
# 5001          37.1  2.0
# 5002          57.3  2.0
# 5003          68.9  1.0
# 5004          66.8  5.0
# 5005          34.1  1.0

# %%
df_1.iloc[4, 2]
# Out:
# 'Facturación'

# %%
print("reg")
df_1.iloc[2:5, 2:7]
# Out:
# reg
#            fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig
# id_ticket
# 5001       2026-01-05     120      Entrega     Media       1        Web
# 5002       2026-01-08     115      Entrega     Media       2     Tienda
# 5003       2026-01-09     110     Producto      Alta       3        Web
# 5004       2026-01-12     115     Producto      Baja       4     Tienda
# 5005       2026-01-11     120  Facturación      Baja       5        Web

# %%
print("reg")
df_1.iloc[2:5, 2:7]
# Out:
# reg
#              cat_incid prioridad  st_cod canal_orig reg
# id_ticket
# 5003          Producto      Alta       3        Web  AR
# 5004          Producto      Baja       4     Tienda  CL
# 5005       Facturación      Baja       5        Web  MX

# %%
df_1.index
# Out:
# RangeIndex(start=5001, stop=5051, step=1, name='id_ticket')

# %%
df_1 = df_1.reset_index()

# %%
df_1.head()
# Out:
#    id_ticket  fecha_alta  id_cli    cat_incid prioridad  st_cod canal_orig  \
# 0       5001  2026-01-05     120      Entrega     Media       1        Web
# 1       5002  2026-01-08     115      Entrega     Media       2     Tienda
# 2       5003  2026-01-09     110     Producto      Alta       3        Web
# 3       5004  2026-01-12     115     Producto      Baja       4     Tienda
# 4       5005  2026-01-11     120  Facturación      Baja       5        Web
#
#   reg  hrs_res  nps
# 0  CL     37.1  2.0
# 1  MX     57.3  2.0
# 2  AR     68.9  1.0
# 3  CL     66.8  5.0
# 4  MX     34.1  1.0

# %%
region = df_1[df_1["reg"] == "MX"]
region
# Out:
#     id_ticket  fecha_alta  id_cli    cat_incid prioridad  st_cod   canal_orig  \
# 1        5002  2026-01-08     115      Entrega     Media       2       Tienda
# 4        5005  2026-01-11     120  Facturación      Baja       5          Web
# 7        5008  2026-01-16     107      Entrega      Baja       3  Marketplace
# 20       5021  2026-02-07     109      Técnico      Baja       1  Marketplace
# 22       5023  2026-02-12     115     Producto      Alta       3  Marketplace
# 23       5024  2026-02-13     108     Producto      Alta       4       Tienda
# 25       5026  2026-02-17     108       Cuenta     Media       1          Web
# 29       5030  2026-02-23     110      Técnico      Alta       5  Marketplace
# 30       5031  2026-02-26     109   Devolución   Crítica       1  Marketplace
# 36       5037  2026-03-06     100      Entrega      Baja       2  Marketplace
# 40       5041  2026-03-14     102      Entrega   Crítica       1       Tienda
# ...

# %%
region.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16 entries, 1 to 48
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_ticket   16 non-null     int64
#  1   fecha_alta  16 non-null     str
#  2   id_cli      16 non-null     int64
#  3   cat_incid   16 non-null     str
#  4   prioridad   16 non-null     str
#  5   st_cod      16 non-null     int64
#  6   canal_orig  16 non-null     str
#  7   reg         16 non-null     str
#  8   hrs_res     16 non-null     float64
#  9   nps         15 non-null     float64
# dtypes: float64(2), int64(3), str(5)
# memory usage: 1.4 KB

# %%
tickets.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_ticket     50 non-null     int64
#  1   fec_apertura  50 non-null     str
#  2   id_cli        50 non-null     int64
#  3   cat_incid     50 non-null     str
#  4   prio          50 non-null     str
#  5   st_cod        50 non-null     int64
#  6   canal_orig    50 non-null     str
#  7   reg           50 non-null     str
#  8   hrs_res       47 non-null     float64
#  9   nps           49 non-null     float64
# dtypes: float64(2), int64(3), str(5)
# memory usage: 4.0 KB

# %%
tickets.sample(5)
# Out:
#     id_ticket fec_apertura  id_cli    cat_incid  prio  st_cod   canal_orig  \
# 20       5021   2026-02-07     109      Técnico  Baja       1  Marketplace
# 17       5018   2026-02-03     104      Técnico  Alta       3       Tienda
# 6        5007   2026-01-15     105   Devolución  Alta       2       Tienda
# 34       5035   2026-03-02     102   Devolución  Alta       5       Tienda
# 16       5017   2026-01-31     110  Facturación  Alta       2  Marketplace
#
#    reg  hrs_res  nps
# 20  MX     14.9  1.0
# 17  AR     18.4  4.0
# 6   CL     26.6  4.0
# 34  CL     17.5  4.0
# 16  AR     10.5  4.0

# %%
clientes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_cli          15 non-null     int64
#  1   nombre_cliente  15 non-null     str
#  2   segmento        15 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 492.0 bytes

# %%
estados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   st_cod          5 non-null      int64
#  1   estado_visible  5 non-null      str
#  2   es_final        5 non-null      bool
# dtypes: bool(1), int64(1), str(1)
# memory usage: 217.0 bytes
